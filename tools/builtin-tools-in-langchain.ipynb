# %% [markdown]
# **Built-in Tool - DuckDuckGo Search**

# %%
from langchain_community.tools import DuckDuckGoSearchRun
search_tool = DuckDuckGoSearchRun()
results = search_tool.invoke('latest ipo news')
print(results)
# Out:
# 23 hours ago · Initial Public Offering (IPO) - Get latest information about news on recent & upcoming IPOs, Recent IPO News, New IPO News, IPO News Today, IPO News, IPO Issue Price and more. Learn more about Initial Public Offering, IPO Listing Details Today, visit NSE India. 26 minutes ago · IPOs: Get all the latest news on recent & upcoming IPOs. Find IPO Subscription and allotment status, IPO Reviews on The Economic Times. IPO News: Get all the latest news on recent and upcoming IPOs. Find IPO Subscription and allotment status news, IPO Reviews on Moneycontrol. Detailed information the last 200 IPOs (initial public offerings) on the stock market. Includes IPO prices, dates, total returns and more. Get the latest IPO news today including IPO DRHP filings, approvals, and SEBI announcements in India.

# %% [markdown]
# **Built-in Tool - Shell Tool**

# %%
from langchain_community.tools import ShellTool
shell_tool = ShellTool()
results = shell_tool.invoke('whoami')
print(results)
# Out:
# Executing command:
#  whoami
# ubuntu
